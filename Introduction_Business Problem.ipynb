# %% [markdown]
# # The Battle of Neighborhoods Week 1

# %% [markdown]
# ## Project Background

# %% [markdown]
# London is an ever-growing city, the most populated in the United Kingdom. It has a wide diversity being made up of many groups of different cultures; as wel as being the financial capital of the UK. It is a global hub of business and commerce. The city is a major center for banking and finance, retailing, world trade, transportation, tourism, real estate, new media, traditional media, advertising, legal services, accountancy, insurance, theater, fashion, and the arts in the UK.

# %% [markdown]
# ## Project Description

# %% [markdown]
# This project aims to find a suitable apartment based on location, price and venues. In order to make a comparison and evaluation of the rental options in London, I have set a basis, therefore the apartment in London must meet the following requirements:
#
# The apartment must be 2 bedrooms.
# The price of rent not exceed £1,300 per month
# It must be desirable to have venues such as cafés, Indian restaurant, wine stores, gym, and food shops.

# %% [markdown]
#  ## Target Audience

# %% [markdown]
# The target audience for this will be those (either internal or external migrants) moving to London wanting to rent near its many types of venues.
